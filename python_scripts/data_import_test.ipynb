# %%
import pandas as pd
import numpy as np

imrp_raw = pd.read_csv('https://dp.lowcarboncontracts.uk/dataset/19f1ebee-93b7-4ef4-9465-bba50fa4ad06/resource/866e6a4e-86c7-411e-9464-2ac3ad56ae35/download/imrp_actuals.csv')

# %%
imrp_raw.head
# Out:
# <bound method NDFrame.head of                          IMRP_Date  Settlement_Period  IMRP_Amount
# 0      2016-06-30 00:00:00.0000000                  1        29.55
# 1      2016-06-30 00:00:00.0000000                  2        29.30
# 2      2016-06-30 00:00:00.0000000                  3        28.95
# 3      2016-06-30 00:00:00.0000000                  4        26.00
# 4      2016-06-30 00:00:00.0000000                  5        24.99
# ...                            ...                ...          ...
# 85675  2026-04-08 00:00:00.0000000                 20       145.57
# 85676  2026-04-08 00:00:00.0000000                 21       129.12
# 85677  2026-04-08 00:00:00.0000000                 22       114.39
# 85678  2026-04-08 00:00:00.0000000                 23       102.98
# 85679  2026-04-08 00:00:00.0000000                 24        96.28
#
# [85680 rows x 3 columns]>
