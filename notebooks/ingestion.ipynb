# %%
import duckdb
import pandas as pd

# %%
con = duckdb.connect("../energy_transform/energy_data.duckdb")

print(con.sql(
    "SELECT * FROM INFORMATION_SCHEMA.COLUMNS WHERE table_name = 'demand'").df())

con.close()
# Out:
#    table_catalog table_schema table_name                column_name  \
# 0    energy_data         main     demand                        _id
# 1    energy_data         main     demand            SETTLEMENT_DATE
# 2    energy_data         main     demand          SETTLEMENT_PERIOD
# 3    energy_data         main     demand                         ND
# 4    energy_data         main     demand                        TSD
# 5    energy_data         main     demand       ENGLAND_WALES_DEMAND
# 6    energy_data         main     demand   EMBEDDED_WIND_GENERATION
# 7    energy_data         main     demand     EMBEDDED_WIND_CAPACITY
# 8    energy_data         main     demand  EMBEDDED_SOLAR_GENERATION
# 9    energy_data         main     demand    EMBEDDED_SOLAR_CAPACITY
# 10   energy_data         main     demand                NON_BM_STOR
# 11   energy_data         main     demand       PUMP_STORAGE_PUMPING
# 12   energy_data         main     demand                   IFA_FLOW
# ...
