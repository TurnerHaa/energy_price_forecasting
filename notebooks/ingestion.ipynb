# %%
import duckdb
import pandas as pd

# %%
# Clear database tables if necessary
# con = duckdb.connect("../energy_transform/energy_data.duckdb")

# tables = con.sql(
#     "SELECT DISTINCT table_name FROM INFORMATION_SCHEMA.COLUMNS").df()['table_name'].tolist()

# print(tables) 

# for table in tables:
#     con.sql(
#         f"DROP TABLE {table}"
#     )

# con.close()
# Out:
# ['demand', 'demand_update', 'generation', 'price', 'emissions']
